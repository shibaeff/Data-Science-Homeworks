# %% [markdown]
# <a href="https://colab.research.google.com/github/shibaeff/Data-Science-Homeworks/blob/master/3_dataset_emp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Введение-в-машинное-обучение" data-toc-modified-id="Введение-в-машинное-обучение-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Введение в машинное обучение</a></div><div class="lev2 toc-item"><a href="#Предварительный-анализ-данных" data-toc-modified-id="Предварительный-анализ-данных-11"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Предварительный анализ данных</a></div><div class="lev2 toc-item"><a href="#Описание-данных" data-toc-modified-id="Описание-данных-12"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Описание данных</a></div><div class="lev2 toc-item"><a href="#1)-Смотрим-размер-набора-данных" data-toc-modified-id="1)-Смотрим-размер-набора-данных-13"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>1) Смотрим размер набора данных</a></div><div class="lev2 toc-item"><a href="#2)-Выводим-названия-колонок" data-toc-modified-id="2)-Выводим-названия-колонок-14"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>2) Выводим названия колонок</a></div><div class="lev2 toc-item"><a href="#3)-Смотрим-информацию-по-каждой-колонке" data-toc-modified-id="3)-Смотрим-информацию-по-каждой-колонке-15"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>3) Смотрим информацию по каждой колонке</a></div><div class="lev2 toc-item"><a href="#4)-Выводим-характеристики-каждого-признака" data-toc-modified-id="4)-Выводим-характеристики-каждого-признака-16"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>4) Выводим характеристики каждого признака</a></div><div class="lev2 toc-item"><a href="#5)-Выводим-соотношение-между-1-и-0-для-SeriousDlqin2yrs" data-toc-modified-id="5)-Выводим-соотношение-между-1-и-0-для-SeriousDlqin2yrs-17"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>5) Выводим соотношение между 1 и 0 для SeriousDlqin2yrs</a></div><div class="lev2 toc-item"><a href="#6)-Определим-средний-возраст" data-toc-modified-id="6)-Определим-средний-возраст-18"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>6) Определим средний возраст</a></div><div class="lev2 toc-item"><a href="#7)-Создадим-свобную-табличку-для-SeriousDlqin2yrs-по-признакам:" data-toc-modified-id="7)-Создадим-свобную-табличку-для-SeriousDlqin2yrs-по-признакам:-19"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>7) Создадим свобную табличку для SeriousDlqin2yrs по признакам:</a></div><div class="lev2 toc-item"><a href="#8)-Визуализируем-распределение-переменной-age-для-SeriousDlqin2yrs" data-toc-modified-id="8)-Визуализируем-распределение-переменной-age-для-SeriousDlqin2yrs-110"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>8) Визуализируем распределение переменной age для SeriousDlqin2yrs</a></div><div class="lev2 toc-item"><a href="#9)-Посмотрим-на-частоты-признака-NumberOfDependents" data-toc-modified-id="9)-Посмотрим-на-частоты-признака-NumberOfDependents-111"><span class="toc-item-num">1.11&nbsp;&nbsp;</span>9) Посмотрим на частоты признака NumberOfDependents</a></div><div class="lev2 toc-item"><a href="#10)-Узнаем-максимальное-значение-по-каждому-признаку" data-toc-modified-id="10)-Узнаем-максимальное-значение-по-каждому-признаку-112"><span class="toc-item-num">1.12&nbsp;&nbsp;</span>10) Узнаем максимальное значение по каждому признаку</a></div><div class="lev2 toc-item"><a href="#11)-Выведем-ту-часть-таблицы,-для-которой-значение-признака-age->-65" data-toc-modified-id="11)-Выведем-ту-часть-таблицы,-для-которой-значение-признака-age->-65-113"><span class="toc-item-num">1.13&nbsp;&nbsp;</span>11) Выведем ту часть таблицы, для которой значение признака age &gt; 65</a></div><div class="lev2 toc-item"><a href="#12)-Сгруппируем-таблицу-по-SeriousDlqin2yrs-и-посмотрим-статистику-для-признаков-'RevolvingUtilizationOfUnsecuredLines',-'age',-'DebtRatio'" data-toc-modified-id="12)-Сгруппируем-таблицу-по-SeriousDlqin2yrs-и-посмотрим-статистику-для-признаков-'RevolvingUtilizationOfUnsecuredLines',-'age',-'DebtRatio'-114"><span class="toc-item-num">1.14&nbsp;&nbsp;</span>12) Сгруппируем таблицу по SeriousDlqin2yrs и посмотрим статистику для признаков 'RevolvingUtilizationOfUnsecuredLines', 'age', 'DebtRatio'</a></div><div class="lev2 toc-item"><a href="#13)-Тоже-самое,-только-для-mean,-std,-min,-max" data-toc-modified-id="13)-Тоже-самое,-только-для-mean,-std,-min,-max-115"><span class="toc-item-num">1.15&nbsp;&nbsp;</span>13) Тоже самое, только для mean, std, min, max</a></div><div class="lev2 toc-item"><a href="#14)-Построим-crosstab-для-полей-SeriousDlqin2yrs-и-age" data-toc-modified-id="14)-Построим-crosstab-для-полей-SeriousDlqin2yrs-и-age-116"><span class="toc-item-num">1.16&nbsp;&nbsp;</span>14) Построим crosstab для полей SeriousDlqin2yrs и age</a></div><div class="lev2 toc-item"><a href="#15)-Построим-crosstab-для-полей-SeriousDlqin2yrs-и-age-+-нормализация" data-toc-modified-id="15)-Построим-crosstab-для-полей-SeriousDlqin2yrs-и-age-+-нормализация-117"><span class="toc-item-num">1.17&nbsp;&nbsp;</span>15) Построим crosstab для полей SeriousDlqin2yrs и age + нормализация</a></div>

# %% [markdown]
# # Введение в машинное обучение

# %% [markdown]
# ## Предварительный анализ данных

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bbed2bad-068e-4786-a7d1-1ca8342795d3" name="files[]" multiple disabled />
#      <output id="result-bbed2bad-068e-4786-a7d1-1ca8342795d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cs-training.csv to cs-training.csv

# %%
df = pd.read_csv('./cs-training.csv', sep=',')

# %%
df.head()
# Out:
#    SeriousDlqin2yrs  ...  NumberOfDependents
# 1                 1  ...                 2.0
# 2                 0  ...                 1.0
# 3                 0  ...                 0.0
# 4                 0  ...                 0.0
# 5                 0  ...                 0.0
#
# [5 rows x 11 columns]

# %% [markdown]
# ## Описание данных

# %% [markdown]
# * SeriousDlqin2yrs - Person experienced 90 days past due delinquency or worse
# * RevolvingUtilizationOfUnsecuredLines - Total balance on credit cards and personal lines of credit except real estate and no installment debt like car loans divided by the sum of credit limits
# * age - Age of borrower in years
# * NumberOfTime30-59DaysPastDueNotWorse - Number of times borrower has been 30-59 days past due but no worse in the last 2 years.
# * DebtRatio - Monthly debt payments, alimony,living costs divided by monthy gross income
# * MonthlyIncome - Monthly income
# * NumberOfOpenCreditLinesAndLoans - Number of Open loans (installment like car loan or mortgage) and Lines of credit (e.g. credit cards)
# * NumberOfTimes90DaysLate - Number of times borrower has been 90 days or more past due.
# * NumberRealEstateLoansOrLines - Number of mortgage and real estate loans including home equity lines of credit
# * NumberOfTime60-89DaysPastDueNotWorse - Number of times borrower has been 60-89 days past due but no worse in the last 2 years.
# * NumberOfDependents - Number of dependents in family excluding themselves (spouse, children etc.)

# %% [markdown]
# * SeriousDlqin2yrs - Флаг выхода на просрочку через 90 дней
# * RevolvingUtilizationOfUnsecuredLines - Общий баланс по кредитным картам и личным кредитным линиям, за исключением недвижимости, и без задолженности по кредитам, таким как автокредиты, деленные на сумму кредитных лимитов
# * age - Возраст заёмщика в годах
# * NumberOfTime30-59DaysPastDueNotWorse - Сколько раз заемщик просрочил выплату не более, чем на 30-59 дней, за последние 2 года.
# * DebtRatio - Ежемесячные платежи по долгам, алименты и прожиточные расходы, делённые на месячный валовый доход
# * MonthlyIncome - Ежемесячный доход
# * NumberOfOpenCreditLinesAndLoans - Количество открытых кредитов (например, автокредит или закладная, кредитные карты и т.д.)
# * NumberOfTimes90DaysLate - Сколько раз заёмщик просрочил выплату на 90 дней и более.
# * NumberRealEstateLoansOrLines - Количество ипотечных кредитов и кредитов на недвижимость
# * NumberOfTime60-89DaysPastDueNotWorse - Сколько раз заёмщик просрочил выплату не более, чем на 60-89 дней, за последние 2 года.
# * NumberOfDependents - Количество иждивенцев в семье, исключая самого заёмщика (супруга, дети и т.д.)

# %% [markdown]
# ## 1) Смотрим размер набора данных

# %% [markdown]
# см. shape

# %%
df.shape
# Out:
# (150000, 11)

# %% [markdown]
# ## 2) Выводим названия колонок

# %% [markdown]
# см. columns

# %%
df.columns
# Out:
# Index([u'SeriousDlqin2yrs', u'RevolvingUtilizationOfUnsecuredLines', u'age',
#        u'NumberOfTime30-59DaysPastDueNotWorse', u'DebtRatio', u'MonthlyIncome',
#        u'NumberOfOpenCreditLinesAndLoans', u'NumberOfTimes90DaysLate',
#        u'NumberRealEstateLoansOrLines',
#        u'NumberOfTime60-89DaysPastDueNotWorse', u'NumberOfDependents'],
#       dtype='object')

# %% [markdown]
# ## 3) Смотрим информацию по каждой колонке

# %% [markdown]
# см. info

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150000 entries, 1 to 150000
# Data columns (total 11 columns):
# SeriousDlqin2yrs                        150000 non-null int64
# RevolvingUtilizationOfUnsecuredLines    150000 non-null float64
# age                                     150000 non-null int64
# NumberOfTime30-59DaysPastDueNotWorse    150000 non-null int64
# DebtRatio                               150000 non-null float64
# MonthlyIncome                           120269 non-null float64
# NumberOfOpenCreditLinesAndLoans         150000 non-null int64
# NumberOfTimes90DaysLate                 150000 non-null int64
# NumberRealEstateLoansOrLines            150000 non-null int64
# NumberOfTime60-89DaysPastDueNotWorse    150000 non-null int64
# NumberOfDependents                      146076 non-null float64
# dtypes: float64(4), int64(7)
# memory usage: 13.7 MB

# %% [markdown]
# ## 4) Выводим характеристики каждого признака

# %% [markdown]
# см. describe

# %%
df.describe()
# Out:
#        SeriousDlqin2yrs  ...  NumberOfDependents
# count     150000.000000  ...       146076.000000
# mean           0.066840  ...            0.757222
# std            0.249746  ...            1.115086
# min            0.000000  ...            0.000000
# 25%            0.000000  ...            0.000000
# 50%            0.000000  ...            0.000000
# 75%            0.000000  ...            1.000000
# max            1.000000  ...           20.000000
#
# [8 rows x 11 columns]

# %% [markdown]
# ## 5) Выводим соотношение между 1 и 0 для SeriousDlqin2yrs

# %% [markdown]
# см. value_counts

# %%
# Много ли у нас неплтельщиков?))
df['SeriousDlqin2yrs'].value_counts()
# Hmmm. Time to pay the debts!!!
# Out:
# 0    139974
# 1     10026
# Name: SeriousDlqin2yrs, dtype: int64

# %% [markdown]
# ## 6) Определим средний возраст

# %% [markdown]
# см. mean

# %%
df['age'].mean()
# Out:
# 52.295206666666665

# %% [markdown]
# ## 7) Создадим свобную табличку для SeriousDlqin2yrs по признакам:
# * NumberOfTime30-59DaysPastDueNotWorse
# * NumberOfTime60-89DaysPastDueNotWorse
# * NumberOfTimes90DaysLate
#
# Соберём по mean

# %% [markdown]
# см. pivot_table

# %%
df.pivot_table(index='SeriousDlqin2yrs', values=['NumberOfTime30-59DaysPastDueNotWorse', 'NumberOfTime60-89DaysPastDueNotWorse', 'NumberOfTimes90DaysLate'], aggfunc=np.mean)
# Out:
#                   NumberOfTime30-59DaysPastDueNotWorse  ...  NumberOfTimes90DaysLate
# SeriousDlqin2yrs                                        ...
# 0                                             0.280109  ...                 0.135225
# 1                                             2.388490  ...                 2.091362
#
# [2 rows x 3 columns]

# %% [markdown]
# ## 8) Визуализируем распределение переменной age для SeriousDlqin2yrs

# %% [markdown]
# см. hist

# %%
ax=df.hist(column='age', by='SeriousDlqin2yrs')

# %% [markdown]
# ## 9) Посмотрим на частоты признака NumberOfDependents

# %% [markdown]
# см. value_counts + normalize

# %%
df['NumberOfDependents'].value_counts(normalize=True) * 100 # in %
# Out:
# 0.0     59.490950
# 1.0     18.015280
# 2.0     13.364276
# 3.0      6.491826
# 4.0      1.959254
# 5.0      0.510693
# 6.0      0.108163
# 7.0      0.034913
# 8.0      0.016430
# 9.0      0.003423
# 10.0     0.003423
# 13.0     0.000685
# 20.0     0.000685
# Name: NumberOfDependents, dtype: float64

# %% [markdown]
# ## 10) Узнаем максимальное значение по каждому признаку

# %% [markdown]
# см. apply + max

# %%
df.apply(np.max)
# Out:
# SeriousDlqin2yrs                              1.0
# RevolvingUtilizationOfUnsecuredLines      50708.0
# age                                         109.0
# NumberOfTime30-59DaysPastDueNotWorse         98.0
# DebtRatio                                329664.0
# MonthlyIncome                           3008750.0
# NumberOfOpenCreditLinesAndLoans              58.0
# NumberOfTimes90DaysLate                      98.0
# NumberRealEstateLoansOrLines                 54.0
# NumberOfTime60-89DaysPastDueNotWorse         98.0
# NumberOfDependents                           20.0
# dtype: float64

# %% [markdown]
# ## 11) Выведем ту часть таблицы, для которой значение признака age > 65

# %% [markdown]
# см. map + lambda

# %%
df[df['age'] > 65]
# Out:
#         SeriousDlqin2yrs  ...  NumberOfDependents
# 6                      0  ...                 1.0
# 15                     0  ...                 0.0
# 17                     0  ...                 0.0
# 28                     0  ...                 1.0
# 38                     0  ...                 1.0
# 42                     0  ...                 0.0
# 45                     0  ...                 0.0
# 46                     0  ...                 2.0
# 50                     0  ...                 0.0
# 51                     0  ...                 0.0
# 62                     0  ...                 0.0
# 63                     0  ...                 0.0
# 66                     0  ...                 0.0
# 72                     0  ...                 0.0
# 79                     0  ...                 1.0
# 82                     0  ...                 0.0
# 92                     0  ...                 0.0
# 100                    0  ...                 0.0
# ...

# %% [markdown]
# ## 12) Сгруппируем таблицу по SeriousDlqin2yrs и посмотрим статистику для признаков 'RevolvingUtilizationOfUnsecuredLines', 'age', 'DebtRatio'

# %% [markdown]
# см. groupby + describe(percentiles=[])

# %%
df[['age', 'SeriousDlqin2yrs', 'DebtRatio', 'RevolvingUtilizationOfUnsecuredLines']].groupby('SeriousDlqin2yrs').describe()
# Out:
#                        age                        ... RevolvingUtilizationOfUnsecuredLines
#                      count       mean        std  ...                                  50%       75%      max
# SeriousDlqin2yrs                                  ...
# 0                 139974.0  52.751375  14.791079  ...                             0.133288  0.487686  50708.0
# 1                  10026.0  45.926591  12.916289  ...                             0.838853  1.000000   8328.0
#
# [2 rows x 24 columns]

# %% [markdown]
# ## 13) Тоже самое, только для mean, std, min, max

# %% [markdown]
# см. groupby + agg + [np.mean, np.std, np.min, np.max]

# %%
# [print(feature) for feature in ['age', 'DebtRatio', 'RevolvingUtilizationOfUnsecuredLines']]
groupped = df.groupby('SeriousDlqin2yrs')['age', 'DebtRatio', 'RevolvingUtilizationOfUnsecuredLines']
groupped.agg([np.mean, np.std, np.min, np.max])
# Out:
#                         age                  ... RevolvingUtilizationOfUnsecuredLines
#                        mean        std amin  ...                                  std amin     amax
# SeriousDlqin2yrs                             ...
# 0                 52.751375  14.791079    0  ...                           256.126350  0.0  50708.0
# 1                 45.926591  12.916289   21  ...                           131.835778  0.0   8328.0
#
# [2 rows x 12 columns]

# %% [markdown]
# ## 14) Построим crosstab для полей SeriousDlqin2yrs и age

# %% [markdown]
# см. crosstab

# %%
pd.crosstab(df['SeriousDlqin2yrs'], df['age'])
# Out:
# age               0    21   22   23   24   25   ...  101  102  103  105  107  109
# SeriousDlqin2yrs                                ...
# 0                   1  170  398  571  718  832  ...    2    3    3    1    1    2
# 1                   0   13   36   70   98  121  ...    1    0    0    0    0    0
#
# [2 rows x 86 columns]

# %% [markdown]
# ## 15) Построим crosstab для полей SeriousDlqin2yrs и age + нормализация

# %% [markdown]
# см. crosstab + normalize=True

# %%
pd.crosstab(df['SeriousDlqin2yrs'], df['age'], normalize=True)
# Out:
# age                    0         21        22   ...       105       107       109
# SeriousDlqin2yrs                                ...
# 0                 0.000007  0.001133  0.002653  ...  0.000007  0.000007  0.000013
# 1                 0.000000  0.000087  0.000240  ...  0.000000  0.000000  0.000000
#
# [2 rows x 86 columns]
